# %%
import pandas as pd

# %%
l = ['Vitalis', 'Male', 'Programmer']

# %%
d = {'name':'Vitalis', 'Gender':'Male','Prof':'Programmer'}

# %%
#Series
s =pd.Series(l)

# %%
s
# Out:
# 0       Vitalis
# 1          Male
# 2    Programmer
# dtype: object

# %%
s.loc[0]
# Out:
# 'Vitalis'

# %%
s = pd.Series(d)

# %%
s
# Out:
# Gender          Male
# Prof      Programmer
# name         Vitalis
# dtype: object

# %%
s['name']
# Out:
# 'Vitalis'

# %%
mult_dict = {
    "name": ['Vitalis', 'Solomon'],
    "prof": ['Software', 'CS']
}

# %%
df = pd.DataFrame(mult_dict)

# %%
df
# Out:
#       name      prof
# 0  Vitalis  Software
# 1  Solomon        CS

# %%
df.tail(1)
# Out:
#       name prof
# 1  Solomon   CS

# %%
df.describe()
# Out:
#            name      prof
# count         2         2
# unique        2         2
# top     Vitalis  Software
# freq          1         1

# %%
df.shape
# Out:
# (2, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
# name    2 non-null object
# prof    2 non-null object
# dtypes: object(2)
# memory usage: 112.0+ bytes

# %% [markdown]
# Function to periodically read data

# %%
df = pd.read_csv('./titanic.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Gender',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# %matplotlib inline
df.groupby(['Gender']).size()
# Out:
# Gender
# female    314
# male      577
# dtype: int64

# %%
df.groupby(['Gender', 'Pclass']).size()
# Out:
# Gender  Pclass
# female  1          94
#         2          76
#         3         144
# male    1         122
#         2         108
#         3         347
# dtype: int64

# %%
df.groupby(['Gender', 'Pclass']).size().unstack().plot(kind='bar')

# %%
ax = df.groupby(['Pclass', 'Survived']).size().unstack().plot(kind='bar', title='Survival rates by class')
ax.set(xlabel='Class, 1=Top, 2=Middle Class, 3- Wakanda', ylabel='# of survivors')
# Out:
# [Text(0,0.5,'# of survivors'),
#  Text(0.5,0,'Class, 1=Top, 2=Middle Class, 3- Wakanda')]

# %%
pd.crosstab(df['Gender'], df['Survived'])
# Out:
# Survived    0    1
# Gender
# female     81  233
# male      468  109

# %%
df['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df['Age'].plot(kind='box')

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df[df['Age']==80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#     Gender   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630   male  80.0      0      0  27042  30.0   A23        S

# %%
df['Age'].plot(kind='box')

# %%
df['Age'].values
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  ,   nan, 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  ,   nan,
#        31.  ,   nan, 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  ,   nan,
#        19.  ,   nan,   nan, 40.  ,   nan,   nan, 66.  , 28.  , 42.  ,
#          nan, 21.  , 18.  , 14.  , 40.  , 27.  ,   nan,  3.  , 19.  ,
#          nan,   nan,   nan,   nan, 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  ,   nan, 21.  , 28.5 ,  5.  , 11.  , 22.  , 38.  , 45.  ,
#         4.  ,   nan,   nan, 29.  , 19.  , 17.  , 26.  , 32.  , 16.  ,
#        21.  , 26.  , 32.  , 25.  ,   nan,   nan,  0.83, 30.  , 22.  ,
#        29.  ,   nan, 28.  , 17.  , 33.  , 16.  ,   nan, 23.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  ,   nan, 71.  , 23.  , 34.  ,
#        34.  , 28.  ,   nan, 21.  , 33.  , 37.  , 28.  , 21.  ,   nan,
#        38.  ,   nan, 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 ,
# ...
